# %%
import pandas as pd

# %%
path = r'D:\Projects\cvm-demonstracoes-financeiras\extracted_data\concat_csv\itr_cia_aberta_DFC_MD_con_2011-2024.csv'

df = pd.read_csv(path)

# %%
df = df[['CNPJ_CIA', 'DENOM_CIA', 'CD_CVM', 'VL_CONTA']]
df[df['DENOM_CIA'] == 'VALE S.A.']
# Out:
#                    CNPJ_CIA  DENOM_CIA  CD_CVM     VL_CONTA
# 86576    33.592.510/0001-54  VALE S.A.    4170  214662114.0
# 86577    33.592.510/0001-54  VALE S.A.    4170  217320211.0
# 86578    33.592.510/0001-54  VALE S.A.    4170   54268731.0
# 86579    33.592.510/0001-54  VALE S.A.    4170   46568993.0
# 86580    33.592.510/0001-54  VALE S.A.    4170   13468958.0
# ...                     ...        ...     ...          ...
# 1786813  33.592.510/0001-54  VALE S.A.    4170          0.0
# 1786814  33.592.510/0001-54  VALE S.A.    4170          0.0
# 1786815  33.592.510/0001-54  VALE S.A.    4170          0.0
# 1786816  33.592.510/0001-54  VALE S.A.    4170          0.0
# 1786817  33.592.510/0001-54  VALE S.A.    4170          0.0
#
# [4632 rows x 4 columns]

# %%
# df.to_hdf('dados2.h5', key='df', mode='w')

# %%
df1 = pd.read_hdf(r'D:\Projects\cvm-demonstracoes-financeiras\Scripts\.CVM\demonstracoes_financeiras\data\itr_cia_aberta_DFC_MD_con_2011-2024.h5')

# %%
df1
# Out:
#                 CNPJ_CIA    DT_REFER  VERSAO  \
# 0     00.070.698/0001-11  2011-03-31       1
# 1     00.070.698/0001-11  2011-03-31       1
# 2     00.070.698/0001-11  2011-03-31       1
# 3     00.070.698/0001-11  2011-03-31       1
# 4     00.070.698/0001-11  2011-03-31       1
# ...                  ...         ...     ...
# 2135  97.191.902/0001-94  2023-03-31       1
# 2136  97.191.902/0001-94  2023-03-31       1
# 2137  97.191.902/0001-94  2023-03-31       1
# 2138  97.191.902/0001-94  2023-03-31       1
# 2139  97.191.902/0001-94  2023-03-31       1
#
#                                    DENOM_CIA  CD_CVM  \
# 0     COMPANHIA ENERGÉTICA DE BRASÍLIA - CEB   14451
# 1     COMPANHIA ENERGÉTICA DE BRASÍLIA - CEB   14451
# 2     COMPANHIA ENERGÉTICA DE BRASÍLIA - CEB   14451
# 3     COMPANHIA ENERGÉTICA DE BRASÍLIA - CEB   14451
# 4     COMPANHIA ENERGÉTICA DE BRASÍLIA - CEB   14451
# ...                                      ...     ...
# ...
